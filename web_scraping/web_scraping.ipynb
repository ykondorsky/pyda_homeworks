# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from datetime import datetime
from datetime import timedelta
import time
import json

# %%
keywords = ['коронавирус', 'intel', 'sql']
posts_df = pd.DataFrame()

# запрашиваем страницу с превью свежих статей
preview_page = BeautifulSoup(requests.get('https://habr.com/ru/all/').text, 'html.parser')

# выбираем все html-теги, соответствующие статьям
posts = preview_page.find_all('article', class_='post')

for post in posts:
    # получаем ссылку на пост
    title_element = post.find('a', class_='post__title_link')

    # запрашиваем страницу с полной версией статьи
    article_page = BeautifulSoup(requests.get(title_element.attrs.get('href')).text, 'html.parser')
    time.sleep(0.1)

    # выбираем полезное содержимое страницы
    content = article_page.find('article', class_='post_full')
    
    # выполняем поиск по ключевым словам
    for keyword in keywords:
        tags = content.find_all(True, string = re.compile(keyword, flags = re.IGNORECASE))
        if tags:
                # название статьи и ссылка уже есть. Получаем дату и полный текст
                post_date = article_page.find('meta', property="aiturec:datetime")
                post_text = article_page.find('div', class_='post__text')
                row = ({'Дата' : post_date.attrs.get('content')[:10],
                        'Заголовок': title_element.string, 
                        'Ссылка': title_element.attrs.get('href'),
                        'Текст статьи' : post_text.text})
                posts_df = pd.concat([posts_df, pd.DataFrame([row])])  
                # если найдено хоть одно из ключевых слов, дальше продолжать цикл по keywords не имеет смысла
                break   
                
posts_df = posts_df.reset_index().loc[:, posts_df.reset_index().columns != 'index']
posts_df
# Out:
#          Дата                                          Заголовок  \
# 0  2021-02-15  Как получить субтитрированный поток в RTMP из SDI
# 1  2021-02-15  Перспективы разработчика в автоматизации тести...
# 2  2021-02-15                  Публикация Go приложения в GitHub
# 3  2021-02-15  Быстрый прототип IIoT-решения на Raspberry PI ...
# 4  2021-02-15     Как селф-сервис BI убивает кровавый энтерпрайз
# 5  2021-02-14  FOSS News №56 – дайджест материалов о свободно...
#
#                                               Ссылка  \
# 0                   https://habr.com/ru/post/542436/
# 1     https://habr.com/ru/company/veeam/blog/541572/
# 2                   https://habr.com/ru/post/542410/
# 3  https://habr.com/ru/company/glowbyte/blog/538682/
# 4  https://habr.com/ru/company/rostelecom/blog/54...
# 5                   https://habr.com/ru/post/542360/
#
#                                         Текст статьи
# 0  Возникла задача получить из SDI сигнала трансл...
# 1  Как и многим, нам в Veeam нужны разработчики а...
# 2  Пост представляет собой контрольный список (ch...
# 3  Это вторая часть из цикла статей про прототипи...
# 4  Привет, меня зовут Владимир Шилов, я руководит...
# 5  \n\nВсем привет!\nПродолжаем дайджесты новосте...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<почта> - <дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
emails = ['petrovvv@gmail.com', 'xxx@ya.ru', 'kolya123@yandex.ru']

# %%
url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
payload = {'emailAddresses': emails}
headers = {
        'Host': 'identityprotection.avast.com',
        'Connection': 'keep-alive',
        'Content-Length': '32',
        'sec-ch-ua': '"Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"',
        'Accept': 'application/json, text/plain, */*',
        'Vaar-Version': '0',
        'sec-ch-ua-mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
        'Vaar-Header-App-Product': 'hackcheck-web-avast',
        'Content-Type': 'application/json;charset=UTF-8',
        'Origin': 'https://www.avast.com',
        'Sec-Fetch-Site': 'same-site',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://www.avast.com/',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7'
        }
    
response = requests.post(url, data = json.dumps(payload), headers=headers)

# %%
# из-за сложной структуры ответа необходима дополнительная функция,
# чтобы получить e-mail, по которому выводится информация о сливе
def get_email(breach_id):
    for key, value in res_dict['summary'].items():
        if breach_id in value['breaches']:
            return key

res_dict = json.loads(response.text)
df = pd.DataFrame()

for key in res_dict['breaches']:
    row = ({'e-mail' : get_email(int(key)),
            'Дата': res_dict['breaches'][key]['publishDate'][:10], 
            'Источник': res_dict['breaches'][key]['site'],
            'Описание' : res_dict['breaches'][key]['description']})
    df = pd.concat([df, pd.DataFrame([row])])
df = df.reset_index().loc[:, df.reset_index().columns != 'index']
df
# Out:
#                 e-mail        Дата             Источник  \
# 0            xxx@ya.ru  2016-11-07       ir.netease.com
# 1            xxx@ya.ru  2020-07-30             hurb.com
# 2   petrovvv@gmail.com  2016-10-21          myspace.com
# 3            xxx@ya.ru  2016-11-01               qip.ru
# 4            xxx@ya.ru  2019-12-05      wowprogress.com
# 5            xxx@ya.ru  2017-11-04       myheritage.com
# 6            xxx@ya.ru  2020-02-06  flyffpenya-shop.com
# 7   kolya123@yandex.ru  2017-02-14       parapa.mail.ru
# 8            xxx@ya.ru  2020-02-06   cityofvillains.com
# 9            xxx@ya.ru  2016-10-24          dropbox.com
# 10  petrovvv@gmail.com  2016-10-29               vk.com
# 11  kolya123@yandex.ru  2020-11-05         vimeworld.ru
# 12  kolya123@yandex.ru  2017-02-14        cfire.mail.ru
# 13           xxx@ya.ru  2017-03-15           wanadoo.fr
#
#                                              Описание
# 0   In October 2015, the Chinese internet and gami...
# 1   In March 2019, the Brazilian travel agency Her...
# 2   Shortly before the 2016 Memorial Day weekend, ...
# 3   In 2011, Russian instant messaging service pro...
# 4   At an unconfirmed date, the World of Warcraft ...
# 5   In October 2017, a customer database belonging...
# 6   In 2015, online gaming shop Flyffpenya Shop wa...
# 7   In July and August 2016, two criminals execute...
# 8   In January 2015, the online role-playing game ...
# 9   Cloud storage company Dropbox suffered a major...
# 10  Popular Russian social networking platform VKo...
# 11  In January 2018, the Russian Minecraft server ...
# 12  In July and August of 2016, two criminals carr...
# 13  At an unconfirmed date Orange (Wanadoo)'s user...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %%
WALLGET_REQUEST = 'https://api.vk.com/method/wall.get?'

params = {
    'access_token': '',
    'v': '5.130',
    'owner_id' : -30159897, # группа Нетологии
    'count': 50
}

res = requests.get(WALLGET_REQUEST, params)

# %%
res_dict = json.loads(res.text)

df = pd.DataFrame()
for post in res_dict['response']['items']:
    row = ({'Дата' : datetime.fromtimestamp(post['date']),
            'Сcылка': 'https://vk.com/netology?w=wall-30159897_' + str(post['id']),
            'Текст записи': post['text'],
            'Лайки': post['likes']['count'],
            'Репосты': post['reposts']['count'],
            'Комментарии': post['comments']['count']})
    df = pd.concat([df, pd.DataFrame([row])])
    
df = df.reset_index().loc[:, df.reset_index().columns != 'index']
df.head()
# Out:
#                  Дата                                         Сcылка  \
# 0 2021-02-14 14:56:00  https://vk.com/netology?w=wall-30159897_78354
# 1 2021-02-15 10:41:00  https://vk.com/netology?w=wall-30159897_78358
# 2 2021-02-13 15:49:00  https://vk.com/netology?w=wall-30159897_78352
# 3 2021-02-13 11:49:00  https://vk.com/netology?w=wall-30159897_78350
# 4 2021-02-12 17:41:00  https://vk.com/netology?w=wall-30159897_78341
#
#                                         Текст записи  Лайки  Репосты  \
# 0  «Жизнь как коробка шоколадных конфет: никогда ...     11        7
# 1  Направлений в дизайне много: можно делать рекл...      6        2
# 2  *партнёрский пост* \n \n26-28 февраля пройдёт ...     10        8
# 3  Собрали статьи для начинающих Java-разработчик...     10        6
# 4  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...     13        2
#
#    Комментарии
# 0            3
# 1            0
# 2            0
# 3            0
# 4            6

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
